# %%
for i in range(0,20):
    print(i)

# %%
for i in range(10,20):
    print(i)

# %%
list=[10,20,14,55,43,87,76]
print("number of item in the lists:")
print(len(list))
# Out:
# number of item in the lists:
# 7

# %%
txt="Aritifical Intelligence"
print(txt)
for char in txt:
    if char==" ":
         print()
    else:
         print(char)
# Out:
# Aritifical Intelligence
# A
# r
# i
# t
# i
# f
# i
# c
# a
# l
#
# I
# n
# t
# e
# l
# l
# i
# g
# e
# n
# c
# e

# %%
print("-Your Name-")
print("-Your Age-")
print("-Your Profession-")
# Out:
# -Your Name-
# -Your Age-
# -Your Profession-

# %%
t=(1,'Welcome',2,'hope')
print(t)
# Out:
# (1, 'Welcome', 2, 'hope')

# %%
a=1
b='Welcome'
c=2
d='hope'
t=(a,b,c,d)
print(t)
# Out:
# (1, 'Welcome', 2, 'hope')

# %%
print((0,1,2,3),('python','hope'))
# Out:
# (0, 1, 2, 3) ('python', 'hope')

# %%
a=(0,1,2,3)
b=('python','hope')
t=(a,b)
print(t)
# Out:
# ((0, 1, 2, 3), ('python', 'hope'))

# %%
numbers = (20, 10, 16, 19, 25, 1, 276, 188)
print(numbers)
for num in numbers:
    print(f"{num} is odd")
# Out:
# (20, 10, 16, 19, 25, 1, 276, 188)
# 20 is odd
# 10 is odd
# 16 is odd
# 19 is odd
# 25 is odd
# 1 is odd
# 276 is odd
# 188 is odd
