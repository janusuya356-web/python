# %%
print("HOPE AI")

# %%
name=input("Enter a institue name:")
print(name)

# %%
name=input("Enter your name:")
age=int(input("enter your age:"))
schoolname=input("enter your school name:")
degree=input("enter your degree:")
# Out:
# Enter your name: anu
# enter your age: 22
# enter your school name: slv
# enter your degree: Msc

# %%
a=10
b=20
add=a+b
print(add)
# Out:
# 30

# %%
a=10
b=20
sub=a-b
print(sub)
# Out:
# -10

# %%
a=10
b=20
mul=a*b
print(mul)
# Out:
# 200

# %%
a=76
b=31
float=a/b
print(float)
# Out:
# 2.4516129032258065

# %%
a=76
b=31
floor=a//b
print(floor)
# Out:
# 2

# %%
a=76
b=31
modulo=a%b
print(modulo)
# Out:
# 14

# %%
a=4
b=4
power=a**b
print(power)
# Out:
# 256
