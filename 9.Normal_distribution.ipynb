# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("pre_placement.csv")
dataset
# Out:
#      sl_no  gender  ssc_p   ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1  female  67.00  others     99  central  commerce      76.0
# 1        2  female  45.00  others     95  central  commerce      84.0
# 2        3  female  88.00  others     86  central  commerce      79.0
# 3        4  female  88.00  others     89  central  commerce      86.0
# 4        5  female  44.99  others     89  central  commerce      45.0
# ..     ...     ...    ...     ...    ...      ...       ...       ...
# 100    101    male  79.00  others     45   others  commerce      56.0
# 101    102    male  86.00  others     37   others  commerce      86.0
# 102    103    male  45.00  others     95   others  commerce      89.0
# 103    104    male  37.00  others     86   others      Arts      89.0
# 104    105    male  78.00  others     89   others      Arts      76.0
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary  gender_male  \
# 0        1  67.00     99      76.0       25     76   25262        False
# 1        2  45.00     95      84.0       52     84   84623        False
# 2        3  88.00     86      79.0       95     79   50000        False
# 3        4  88.00     89      86.0       86     86   65632        False
# 4        5  44.99     89      45.0       89     45   50000        False
# ..     ...    ...    ...       ...      ...    ...     ...          ...
# 100    101  79.00     45      56.0       86     86   25262         True
# 101    102  86.00     37      86.0       45     45    5000         True
# 102    103  45.00     95      89.0       37     37   50000         True
# 103    104  37.00     86      89.0       51     79   60000         True
# 104    105  78.00     89      76.0       75     86   50000         True
#
#      ssc_b_others  hsc_b_central   hsc_b_others  hsc_s_commerce  \
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no                     0
# ssc_p                     0
# hsc_p                     0
# degree_p                  0
# etest_p                   0
# mba_p                     0
# salary                    0
# gender_male               0
# ssc_b_others              0
# hsc_b_central             0
# hsc_b_others              0
# hsc_s_commerce            0
# hsc_s_science             0
# degree_t_sci&tech         0
# workex_yes                0
# specialisation_mkt&hr     0
# specialisation_mrt&fin    0
# status_placed             0
# dtype: int64

# %%
#!pip install seaborn

# %%
import seaborn as sns

# %%
sns.distplot(dataset["ssc_p"] )
# Out:
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
from matplotlib import pyplot
from scipy.stats import norm
import seaborn as sns
import numpy as np

# %%
dataset=(startrange,endrange)
startrange=40
endrange=70
ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
pyplot.axvline(startrange,color='red')
pyplot.axvline(endrange,color='red')

# %%
sample=dataset
sample_mean =np.mean(dataset)
sample_std =np.std(dataset)
print('mean=%.3f,standard Devation=%.3f' %(sample_mean,sample_std))
dist=norm(sample_mean,sample_std)
pyplot.show()
# Out:
# mean=55.000,standard Devation=15.000
# the area between range

# %%
for value in range(startrange,endrange):
   values=startrange,endrange
probability=[dist.pdf(value) for  value in values]
prob=sum(probability)
print("the area between range({},{}):{}".format(startrange,endrange,sum(probability)))
# Out:
# the area between range(40,70):0.03226276326921911

# %%
dataset=(startrange,endrange)
startrange=40
endrange=70
ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
pyplot.axvline(startrange,color='red')
pyplot.axvline(endrange,color='red')
sample=dataset
sample_mean =np.mean(dataset)
sample_std =np.std(dataset)
print('mean=%.3f,standard Devation=%.3f' %(sample_mean,sample_std))
dist=norm(sample_mean,sample_std)
for value in range(startrange,endrange):
   values=startrange,endrange
probability=[dist.pdf(value) for  value in values]
prob=sum(probability)
print("the area between range({},{}):{}".format(startrange,endrange,sum(probability)))
pyplot.show()
# Out:
# mean=55.000,standard Devation=15.000
# the area between range(40,70):0.03226276326921911

# %%
def probability(dataset,startrange,endrange):
    dataset=(startrange,endrange)
    startrange=40
    endrange=70
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
    pyplot.axvline(startrange,color='red')
    pyplot.axvline(endrange,color='red')
    sample=dataset
    sample_mean =np.mean(dataset)
    sample_std =np.std(dataset)
    print('mean=%.3f,standard Devation=%.3f' %(sample_mean,sample_std))
    dist=norm(sample_mean,sample_std)
    for value in range(startrange,endrange):
       values=startrange,endrange
    probability=[dist.pdf(value) for  value in values]
    prob=sum(probability)
    print("the area between range({},{}):{}".format(startrange,endrange,sum(probability)))
    pyplot.show()
    return probability

# %%
probability(dataset,startrange,endrange)
# Out:
# mean=55.000,standard Devation=15.000
# the area between range(40,70):0.03226276326921911
# [np.float64(0.016131381634609556), np.float64(0.016131381634609556)]
