# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[0]])
print(result)
# Out:
# C:\Users\Techs\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 loaded_model=pickle.load(open("finalized_model_mul_linear.sav",'rb'))
# ----> 2 result=loaded_model.predict([[0]])
#       3 print(result)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
# ...
